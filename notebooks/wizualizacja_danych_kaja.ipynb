# %%
import pandas as pd
kanalzero=pd.read_csv("../data/processed/processed_KanalZero_videos_info.csv")
orb=pd.read_csv("../data/processed/processed_ORB_videos_info.csv")
konop=pd.read_csv("../data/processed/processed_Konopskyy_videos_info.csv")

# %%
kanalzero["published_at"] = pd.to_datetime(kanalzero["published_at"],errors="coerce")
kanalzero = kanalzero.sort_values("published_at")
kanalzero=kanalzero[kanalzero["published_at"]>"2024-01-01"]
kanalzero.head()
# Out:
#           video_id channel_name  \
# 11668  b9LF33G9BLs    KanalZero
# 11667  02OwcddCyCM    KanalZero
# 11666  9uuojyjXzv0    KanalZero
# 11665  gfSAmRC6ymU    KanalZero
# 11664  E08Ag-H7DJA    KanalZero
#
#                                                    title  \
# 11668  TOMASZ RACZEK W KANALE ZERO! #kanalzero #racze...
# 11667  TEDE W KANALE ZERO! #kanalzero #shorts #tede #...
# 11666  MONIKA GOŹDZIALSKA W KANALE ZERO! #kanalzero #...
# 11665  TOMASZ ROŻEK W KANALE ZERO! #kanalzero #shorts...
# 11664                          JAK POWSTAWAŁ KANAŁ ZERO?
#
#                    published_at  view_count  like_count  comment_count  \
# 11668 2024-01-21 11:26:46+00:00      189948        6297            422
# 11667 2024-01-21 16:00:00+00:00      401826        7426            735
# 11666 2024-01-22 10:18:56+00:00      208974        3625            497
# 11665 2024-01-22 16:27:04+00:00      169744        8505            338
# 11664 2024-01-23 18:00:35+00:00     1156999       69740           6311
#
#        clickbait_score             clickbait_level  engagement_rate_%
# 11668                2     1. Rzetelny / Neutralny               3.32
# 11667                2     1. Rzetelny / Neutralny               1.85
# 11666                2     1. Rzetelny / Neutralny               1.73
# 11665                2     1. Rzetelny / Neutralny               5.01
# 11664                3  2. Lekki marketing newsowy               6.03

# %%
orb["published_at"] = pd.to_datetime(orb["published_at"],errors="coerce")
orb = orb.sort_values("published_at")
orb.head()
# Out:
#         video_id channel_name  \
# 756  977B_6BpQDk          ORB
# 755  Qv0xUWF3LDo          ORB
# 754  yOpaY7l6Rqo          ORB
# 753  bV_UKbOPzWs          ORB
# 752  N35gmWm_auk          ORB
#
#                                                  title  \
# 756                                     Witajcie w ORB
# 755  Holandia pozywa Polskę ?? (ale też wiele więce...
# 754  Czy Polska wyleci z Unii??? Głębsze spojrzenie...
# 753  Nawet nie próbowaliśmy robić poważnego filmu -...
# 752  Zawiesili działalność na 2 tygodnie *NIE ZGADN...
#
#                  published_at  view_count  like_count  comment_count  \
# 756 2020-12-03 17:31:17+00:00        3697         241             11
# 755 2020-12-06 19:29:36+00:00        1904         120              9
# 754 2020-12-10 14:29:16+00:00        3129         142             11
# 753 2020-12-15 21:55:19+00:00        1633         124             10
# 752 2020-12-23 13:20:43+00:00        1315          90             11
#
#      clickbait_score             clickbait_level  engagement_rate_%
# 756                1     1. Rzetelny / Neutralny               6.52
# 755                4  2. Lekki marketing newsowy               6.30
# 754                2     1. Rzetelny / Neutralny               4.54
# 753                1     1. Rzetelny / Neutralny               7.59
# 752                5  2. Lekki marketing newsowy               6.84

# %%
konop["published_at"] = pd.to_datetime(konop["published_at"],errors="coerce")
konop = konop.sort_values("published_at")
konop=konop[konop["published_at"]>"2021-01-01"]
konop.head()
# Out:
#         video_id channel_name  \
# 294  ZeGRCQl5ki8    Konopskyy
# 293  2dcOP1AowUQ    Konopskyy
# 292  -Blt7NoLdVQ    Konopskyy
# 291  xyXdjVZWUGA    Konopskyy
# 290  NaQBiOs3wCc    Konopskyy
#
#                                                  title  \
# 294  PODSUMOWANIE NAJWIĘKSZEJ DRAMY NA POLSKIM TWIT...
# 293  FRIZ KONTRA ZARZUTY O KURS YOUTUBERA (EKIPA, N...
# 292  YOUTUBER NACHODZONY PRZEZ WIDZÓW (MR BEAST, DJ...
# 291  AMONG US UMIERA! (NITRO, SZPAKU, MR BEAST I KO...
# 290  YOUTUBER STRACIŁ 2.000.000$ NA POKEMONY... (MI...
#
#                  published_at  view_count  like_count  comment_count  \
# 294 2021-01-17 17:00:41+00:00      521313       99209           3087
# 293 2021-01-18 17:45:01+00:00      584449      119024           4558
# 292 2021-01-24 16:29:54+00:00      573391       74744           3248
# 291 2021-01-27 17:45:00+00:00      424503       77405           4671
# 290 2021-02-04 17:21:10+00:00      431457       72584           2162
#
#      clickbait_score                      clickbait_level  engagement_rate_%
# 294                7  3. Wysoka manipulacja algorytmiczna              19.03
# 293                6  3. Wysoka manipulacja algorytmiczna              20.37
# 292                4           2. Lekki marketing newsowy              13.04
# 291                5           2. Lekki marketing newsowy              18.23
# 290                6  3. Wysoka manipulacja algorytmiczna              16.82

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
fig,ax=plt.subplots(2,1,figsize=(10,6))
ax[0].plot(kanalzero['published_at'], kanalzero['view_count'])
ax[1].plot(kanalzero['published_at'], kanalzero['clickbait_score'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
fig,ax=plt.subplots(2,1,figsize=(10,6))
ax[0].plot(orb['published_at'], orb['view_count'])
ax[1].plot(orb['published_at'], orb['clickbait_score'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns   
fig,ax=plt.subplots(2,1,figsize=(10,6))
ax[0].plot(konop['published_at'], konop['view_count'])
ax[1].plot(konop['published_at'], konop['clickbait_score'])

# %%
#korelacja pomiedzy wyswietleniami a clickbait_score
macierz=kanalzero['view_count'].corr(kanalzero['clickbait_score'])
print(macierz)
# Out:
# -0.01787114602800617

# %%
#korelacja pomiedzy wyswietleniami a clickbait_score
macierz1=orb['view_count'].corr(orb['clickbait_score'])
print(macierz1)
# Out:
# 0.012179304276416792

# %%
#korelacja pomiedzy wyswietleniami a clickbait_score
macierz2=konop['view_count'].corr(konop['clickbait_score'])
print(macierz2)
# Out:
# -0.1164809011561121

# %%
#tytuly filmikow z najwyzszymi wyswietleniami
top_views_kanalzero = kanalzero.sort_values(by='view_count', ascending=False).head(10)
print(top_views_kanalzero[['title', 'view_count']])
# Out:
#                                                    title  view_count
# 11543   DZIENNIKARSKIE ZERO #1: CAŁA PRAWDA O DERPIENSKI     4338756
# 8110     STANOWSKI WSPOMINA HISTORIĘ Z JEDNYM POLITYKIEM     3827676
# 8136   GODZINA ZERO #86: KRZYSZTOF STANOWSKI I SŁAWOM...     3736842
# 10454  STANOWSKI OŚMIESZYŁ STONOGĘ, DZIENNIKARZY I PO...     3664748
# 10509  DZIENNIKARSKIE ZERO: SZALONY REPORTER (PRZESTĘ...     3621619
# 11511                         MOCNE SŁOWA ELIZY MICHALIK     3254575
# 7947   PREZYDENCKIE ZERO #10: STANOWSKI O DEBACIE, SK...     3188605
# 11343  DZIENNIKARSKIE ZERO #3: KOLEJNY ATAK WYBORCZEJ...     3118569
# 7299            WIECZÓR WYBORCZY W KANALE ZERO - II TURA     3096176
# 9823                   TOMASZ KAMMEL BARDZO GO NIE LUBIŁ     3065775

# %%
#tytuly filmikow z najwyzszymi wyswietleniami
top_views_orb = orb.sort_values(by='view_count', ascending=False).head(10)
print(top_views_orb[['title', 'view_count']])
# Out:
#                                                  title  view_count
# 337   Cyrk Przyjechał - Czyli Pierwsze Obrady Sejmu XD      526635
# 150              Trump VS  Zełenski  - CO SIĘ ODWALIŁO      424937
# 347                       Opozycja Wygrała - Co Dalej?      413416
# 133                 Najlepsze Debaty w Historii Polski      408772
# 349          WYBORY 2023 - Wszystko Co Musisz Wiedzieć      396803
# 111     Trzaskowski vs Mentzen - Grillowanie i Piwo xD      389515
# 352                 Kto Wygrał Debatę w TVP? - Analiza      385083
# 325  Braun z Gaśnicą a Tusk z Rządem - CO TU SIĘ DZ...      383394
# 323            Tusk Przejmuje TVP a PiS się Barykaduje      378350
# 119  Poradnik Wyborczy - Omówienie Kandydatów na Pr...      364365

# %%
#tytuly filmikow z najwyzszymi wyswietleniami
top_views_konop = konop.sort_values(by='view_count', ascending=False).head(10)
print(top_views_konop[['title', 'view_count']])
# Out:
#                                                  title  view_count
# 167               MROCZNA PRZESZŁOŚĆ POLSKIEGO YOUTUBA    14067228
# 106     MAFIA HAZARDOWA POLSKIEGO INTERNETU #KoniecGry     4718017
# 166  POGRĄŻAJĄCE OŚWIADCZENIA INFLUENCERÓW (MARCIN ...     3677057
# 168  GARGAMEL SKREŚLONY Z INTERNETU (PATOSTREAMER D...     2759753
# 199                                    WYBUCH W PRALNI     2660071
# 165  DUBIEL SOBIE ZASZKODZIŁ (PŁATNY TWITTER, PATOS...     2416370
# 115  WARDĘGA ZNISZCZYŁ BOXDELA? (FAME MMA, DUBIEL, ...     2360279
# 113  BOXDEL Z NIEUDANYM "OLBRZYMEM"? (WARDĘGA ODPOW...     2169825
# 114  BOXDEL ZAPOWIADA "APOKALIPSE" INFLUENCERÓW (OJ...     1873114
# 82   OBRZYDLIWY INFLUENCER VS 15-LATKA (ELON MUSK, ...     1841739

# %%
df=pd.read_csv("../data/processed/ZBIORCZY_raport_clickbaitu.csv")
df.head()
# Out:
#       video_id channel_name  \
# 0  p3xGa6yKxxM    KanalZero
# 1  DGhEVGCr8kc    KanalZero
# 2  HShngPHm-rY    KanalZero
# 3  FBGv4bTHCuI    KanalZero
# 4  SyAkC5NR41Q    KanalZero
#
#                                                title          published_at  \
# 0  KRZYSZTOF ŚMISZEK I AGNIESZKA BURZYŃSKA - PORA...  2026-05-20T08:01:45Z
# 1                        OFICJALNY POCZĄTEK ZERO TV!  2026-05-20T07:30:05Z
# 2              FARMY TROLLI WSPOMAGAJĄ MISZALSKIEGO?  2026-05-20T07:14:10Z
# 3  REFERENDUM W KRAKOWIE, INTERNETOWE TROLLE ZNIE...  2026-05-20T07:00:19Z
# 4  CO DALEJ Z AMERYKAŃSKIM WOJSKIEM? I TELEWIZYJN...  2026-05-20T06:58:26Z
#
#    view_count  like_count  comment_count  clickbait_score  \
# 0        7484         262            109                2
# 1        8272         152              5                3
# 2        5010         196             23                3
# 3       24940        2333            296                2
# 4       32665        1087             29                5
#
#               clickbait_level  engagement_rate_%
# 0     1. Rzetelny / Neutralny               3.50
# 1  2. Lekki marketing newsowy               1.84
# 2  2. Lekki marketing newsowy               3.91
# 3     1. Rzetelny / Neutralny               9.35
# 4  2. Lekki marketing newsowy               3.33

# %%
df["published_at"] = pd.to_datetime(df["published_at"],errors="coerce")
df = df.sort_values("published_at")
df=df[df["published_at"]>"2024-01-01"]
df=df[(df['channel_name']!="KanalZero")|(df['view_count']>100000)]
df.head()
# Out:
#           video_id channel_name  \
# 12299  Lk_gHopiOpo          ORB
# 12298  3_8s3e_vufM          ORB
# 12297  fIzqHlWxltQ          ORB
# 11822  Dq5Pg87raRQ    Konopskyy
# 12296  V73OvFHVLfw          ORB
#
#                                                    title  \
# 12299                       Polityczne Podsumowanie Roku
# 12298  Potężna Konferencja Kaczyńskiego - i Wiele Abs...
# 12297            Sąd Najwyższy Kłóci się z Samym Sobą XD
# 11822  KSIĄŻULO W OGNIU KRYTYKI? (JEFFREY EPSTEIN DOK...
# 12296  Wąsik Złapany a Sejm Odwołany XD - Nie serio c...
#
#                    published_at  view_count  like_count  comment_count  \
# 12299 2024-01-01 15:18:55+00:00      230914       12751            329
# 12298 2024-01-03 16:09:25+00:00      292336       15494            653
# 12297 2024-01-05 15:51:53+00:00      252143       12547            797
# 11822 2024-01-07 13:00:12+00:00     1412378       71254           1267
# 12296 2024-01-10 13:00:25+00:00      312882       17191           1246
#
#        clickbait_score             clickbait_level  engagement_rate_%
# 12299                0     1. Rzetelny / Neutralny               5.52
# 12298                3  2. Lekki marketing newsowy               5.30
# 12297                3  2. Lekki marketing newsowy               4.98
# 11822                5  2. Lekki marketing newsowy               5.04
# 12296                4  2. Lekki marketing newsowy               5.49

# %%
plt.figure(figsize=(16,10))
sns.boxplot(y=df['view_count'],x=df['channel_name'])
# Out:
# <Axes: xlabel='channel_name', ylabel='view_count'>

# %%
plt.figure(figsize=(16,10))
sns.boxplot(y=df['clickbait_score'],x=df['channel_name'])
# Out:
# <Axes: xlabel='channel_name', ylabel='clickbait_score'>

# %%
plt.figure(figsize=(16,10))
sns.boxplot(y=df['comment_count'],x=df['channel_name'])
# Out:
# <Axes: xlabel='channel_name', ylabel='comment_count'>

# %%
df=df[df['engagement_rate_%']<=90]
df
# Out:
#           video_id channel_name  \
# 12299  Lk_gHopiOpo          ORB
# 12298  3_8s3e_vufM          ORB
# 12297  fIzqHlWxltQ          ORB
# 11822  Dq5Pg87raRQ    Konopskyy
# 12296  V73OvFHVLfw          ORB
# ...            ...          ...
# 33     MsxXAw0mXOw    KanalZero
# 23     OBmrIXgRQhs    KanalZero
# 21     1Uho3f_aFnA    KanalZero
# 20     J05w2vQL0dM    KanalZero
# 11980  jRKDc8jkJbA          ORB
#
#                                                    title  \
# 12299                       Polityczne Podsumowanie Roku
# 12298  Potężna Konferencja Kaczyńskiego - i Wiele Abs...
# 12297            Sąd Najwyższy Kłóci się z Samym Sobą XD
# 11822  KSIĄŻULO W OGNIU KRYTYKI? (JEFFREY EPSTEIN DOK...
# 12296  Wąsik Złapany a Sejm Odwołany XD - Nie serio c...
# ...                                                  ...
# 33     SROCZYŃSKI: LIBERAŁOWIE NIENAWIDZĄ NAJBARDZIEJ...
# 23        STANOWSKI: STARTUJEMY! KANAŁ ZERO W TELEWIZJI!
# 21     UDAŁO SIĘ! ZERO NA PILOCIE TV NALEŻY DO KANAŁU...
# 20           STANOWSKI: BĘDZIEMY WIĘKSI NIŻ PLANOWALIŚMY
# 11980                                 Policja vs Prawica
#
#                    published_at  view_count  like_count  comment_count  \
# 12299 2024-01-01 15:18:55+00:00      230914       12751            329
# 12298 2024-01-03 16:09:25+00:00      292336       15494            653
# 12297 2024-01-05 15:51:53+00:00      252143       12547            797
# 11822 2024-01-07 13:00:12+00:00     1412378       71254           1267
# 12296 2024-01-10 13:00:25+00:00      312882       17191           1246
# ...                         ...         ...         ...            ...
# 33    2026-05-19 07:04:21+00:00      132096        9734           1541
# 23    2026-05-19 10:58:35+00:00      431746       23545           2436
# 21    2026-05-19 11:32:01+00:00      248343        5457            254
# 20    2026-05-19 11:45:01+00:00      228322        5064            247
# 11980 2026-05-19 12:22:40+00:00       77788        1589            169
#
#        clickbait_score             clickbait_level  engagement_rate_%
# 12299                0     1. Rzetelny / Neutralny               5.52
# 12298                3  2. Lekki marketing newsowy               5.30
# 12297                3  2. Lekki marketing newsowy               4.98
# 11822                5  2. Lekki marketing newsowy               5.04
# 12296                4  2. Lekki marketing newsowy               5.49
# ...                ...                         ...                ...
# 33                   4  2. Lekki marketing newsowy               7.37
# 23                   3  2. Lekki marketing newsowy               5.45
# 21                   3  2. Lekki marketing newsowy               2.20
# 20                   2     1. Rzetelny / Neutralny               2.22
# 11980                2     1. Rzetelny / Neutralny               2.04
#
# [5012 rows x 10 columns]

# %%
plt.figure(figsize=(16,10))
sns.boxplot(y=df['engagement_rate_%'],x=df['channel_name'])
# Out:
# <Axes: xlabel='channel_name', ylabel='engagement_rate_%'>

# %%
plt.figure(figsize=(16,10))
for name, group in df.groupby("channel_name"):
    plt.plot(group["published_at"], group["view_count"], label=name)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x=df["clickbait_score"],y=df["engagement_rate_%"])
# Out:
# <Axes: xlabel='clickbait_score', ylabel='engagement_rate_%'>
